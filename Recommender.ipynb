# %%
import requests
import numpy as np
import pandas as pd
import time
import urllib.parse

# %%
## determine list of board games to base recommendation
username = "TragicBandit"
min_rating = 7.5
max_rating = 10

# %%
base_collection = requests.get('https://boardgamegeek.com/xmlapi/collection/' + username + '?own=1').text

# %%
## get collection data on rated games from a user's collection

def getNextGameData(game_text):
    
    ## get subtype to see if boardgame
    subtype_start = game_text.find('subtype="')
    subtype_end = game_text.find('collid') - 2
    subtype = game_text[subtype_start + len('subtype="'):subtype_end]
    
    if subtype != 'boardgame':
        print(subtype)
        game_dict = {'id': -1, 'name': '', 'rating': ''}
        return game_dict
    
    ## get game id
    id_start = game_text.find('objectid="')
    id_end = game_text.find('"', id_start + len('objectid="'))
    id = int(game_text[id_start + len('objectid="'):id_end])
    
    ## get game name
    name_start = game_text.find('<name sortindex="')
    name_end = game_text.find('</name>', name_start)
    name = game_text[name_start + 3 + len('<name sortindex="'):name_end]
    
    ## get game rating
    rating_start = game_text.find('<rating value="')
    rating_end = game_text.find('"', rating_start + len('<rating value="'))
    try:
        rating = float(game_text[rating_start + len('<rating value="'):rating_end])
    except:
        rating = np.nan
    
    game_dict = {'id': id, 'name': name, 'rating': rating}
                                                
    return game_dict


def getNextGame(content_text):
    item_start = content_text.find('<item ')
    item_end = content_text.find('</item>') + len('</item>')
    item = content_text[item_start:item_end]
    rest_content = content_text[item_end + 1:]
    return item,rest_content

def createCollection(content_text, rated):
    ## initialize empty boardgame_collection
    boardgame_collection = pd.DataFrame(columns=['id', 'name', 'rating'])
    fullboardgame_collection = pd.DataFrame(columns=['id', 'name', 'rating'])
    
    ## get counter for loop
    item_count_start = content_text.find('totalitems="')
    item_count_end = content_text.find('"', item_count_start + len('totalitems="'))
    item_count = int(content_text[item_count_start + len('totalitems="'):item_count_end])
    
    for i in range(item_count):
        next_game, content_text = getNextGame(content_text)
        game_data = getNextGameData(next_game)
        
        if rated == True:
            if (game_data['rating'] >= min_rating) and (game_data['rating'] <= max_rating) and game_data['id'] != -1:
                boardgame_collection = boardgame_collection.append(game_data, ignore_index = True)
            else:
                continue
        else:
            boardgame_collection = boardgame_collection.append(game_data, ignore_index = True)
        
    
    return boardgame_collection

# %%
base_collection_df = createCollection(base_collection, True)
full_collection_df = createCollection(base_collection, False)
print(base_collection_df)
print(full_collection_df)
# Out:
#        id                           name  rating
# 0   68448                      7 Wonders    10.0
# 1   84876        The Castles of Burgundy     9.0
# 2   36218                       Dominion     8.0
# 3  271519                      Ecosystem     8.0
# 4  148228                       Splendor     8.0
# 5    9209                 Ticket to Ride     9.0
# 6  183394  Viticulture Essential Edition     8.0
# 7  266192                       Wingspan    10.0
#         id                                        name  rating
# 0    68448                                   7 Wonders    10.0
# 1   358504  Betrayal at House on the Hill: 3rd Edition     6.0
# 2    84876                     The Castles of Burgundy     9.0
# 3       13                                       CATAN     7.0
# 4    36218                                    Dominion     8.0
# 5   271519                                   Ecosystem     8.0
# 6    65244                            Forbidden Island     6.0
# 7   291457                Gloomhaven: Jaws of the Lion     NaN
# 8    30549                                    Pandemic     6.0
# 9   218603                              Photosynthesis     NaN
# 10  169786                                      Scythe     NaN
# 11  148228                                    Splendor     8.0
# 12    9209                              Ticket to Ride     9.0
# 13  183394               Viticulture Essential Edition     8.0
# 14  266192                                    Wingspan    10.0

# %%
collection_text = requests.get('https://boardgamegeek.com/xmlapi/collection/1000rpm?own=1').text

print(createCollection(collection_text))
# Out:
#          id                                      name  rating
# 0       432                                  6 nimmt!     8.0
# 1     68448                                 7 Wonders     8.0
# 2    204516         878 Vikings: Invasions of England     9.0
# 3         5                                   Acquire     8.0
# 4     22545  Age of Empires III: The Age of Discovery     8.0
# ..      ...                                       ...     ...
# 129  193105               Utopia Engine: Beast Hunter     8.0
# 130   15364                            Vegas Showdown     8.0
# 131   25821    The Werewolves of Miller&#039;s Hollow     8.0
# 132   33643                                Whoowasit?     8.0
# 133   27588                                Zooloretto     8.0
#
# [134 rows x 3 columns]

# %%
## get next comment
def getNextComment(game_text):
    comment_start = game_text.find('<comment ')
    if comment_start == -1:
        return 0,0
    
    comment_end = game_text.find('</comment>') + len('</comment>')
    comment = game_text[comment_start:comment_end]
    rest_comments = game_text[comment_end + 1:]
    return comment,rest_comments


def getCommentInfo(comment_text):
    
    ## get comment username
    username_start = comment_text.find('username="')
    username_end = comment_text.find('"', username_start + len('username="'))
    username = urllib.parse.quote(comment_text[username_start + len('username="'):username_end], safe = '')
    
    ## get comment rating
    rating_start = comment_text.find('rating="')
    rating_end = comment_text.find('"', rating_start + len('rating="'))
    
    try:
        rating = float(comment_text[rating_start + len('rating="'):rating_end])
    except:
        rating = np.nan
    
    comment_dict = {'username': username, 'rating': rating}
    return comment_dict

## get list of usernames
def getGameListUsernames(game_text):
    
    comment_collection = pd.DataFrame(columns=['username', 'rating'])
    while True:
        comment, game_text = getNextComment(game_text)
        if comment == 0: 
            break
        else:
            comment_dict = getCommentInfo(comment)
            
            if (comment_dict['rating'] >= min_rating) and (comment_dict['rating'] <= max_rating):
                comment_collection = comment_collection.append(comment_dict, ignore_index = True)
            continue
            
    return comment_collection

# %%
boardgame_comments = requests.get('https://boardgamegeek.com/xmlapi/boardgame/13?comments=1').text

x = getGameListUsernames(boardgame_comments)

print(x)
# Out:
#               username  rating
# 0           00daniel00    8.00
# 1           100pcBlade    8.00
# 2                1024b    8.25
# 3              14cross    9.00
# 4            1amgreg77    8.70
# 5          1Aspielerin    8.00
# 6             1nf1n1ty    8.00
# 7               200404   10.00
# 8             2ndPlace    8.00
# 9               2ombie    8.00
# 10              31rhcp    9.00
# 11         360_Piranha    8.00
# 12        3kindsofsalt   10.00
# 13          3sapphires   10.00
# 14               47029    8.00
# 15             49xjohn    9.40
# 16               4ndrz    8.00
# 17           4ndySmith    8.00
# 18              5thian   10.00
# 19             80sGirl   10.00
# 20               8one6    8.00
# 21               8tlas    8.00
# 22            95after5   10.00
# 23  A%20Strange%20Aeon   10.00
# 24               A.Men    8.00
# 25              AADA7A    9.00
# 26           aadrian13    8.00
# 27             aandjso    8.00
# 28            aardball    8.80
# 29      Aardvark%20Sam    8.00
# 30            aaron444    8.00
# 31             Aarontu   10.00
# 32        AB%20Special    8.00
# 33               ab999    8.00

# %%
## get usernames for each boardgame

username_df = pd.Series(dtype = 'object')

for index, value in base_collection_df['id'].items():
    
    time.sleep(3)
    boardgame_comments = requests.get('https://boardgamegeek.com/xmlapi/boardgame/' + str(value) +  '?comments=1').text
    
    
    comment_data = getGameListUsernames(boardgame_comments)
    print(comment_data['username'].shape)
    username_df = pd.concat([username_df, comment_data['username']], ignore_index = True)

username_df.drop_duplicates(inplace=True)    
print(username_df)
# Out:
# (51,)
# (67,)
# (54,)
# (39,)
# (44,)
# (42,)
# (58,)
# (63,)
# 0           0lexandr
# 1            1000rpm
# 2         100pcBlade
# 3       144creations
# 4            14cross
#            ...
# 413      Addiction2k
# 414           adh105
# 415           Adio75
# 416        AdMan2015
# 417    AdmiralBanana
# Length: 310, dtype: object

# %%
def scoreUserWeightValue(rated_game_pd):
    weight = 0
    modified_game_pd = rated_game_pd.copy()
    for index, value in base_collection_df['id'].items():
        if len(modified_game_pd[modified_game_pd['id'].isin([value])]) > 0:
            weight = weight + 1
            modified_game_pd = modified_game_pd.drop(modified_game_pd[modified_game_pd['id'] == value].index)
            
        else:
            continue
    
    weight = 1 + (0.2 * weight)
    
    return modified_game_pd, weight
            
def scoreUserWeight(rated_game_pd):
    modified_game_pd, weight = scoreUserWeightValue(rated_game_pd)
    modified_game_pd['score'] = weight
    
    return modified_game_pd
    
def scoreUsernameRatings(username):
    time.sleep(2)
    rated_game_pd = createCollection(requests.get('https://boardgamegeek.com/xmlapi/collection/' + username + '?own=1').text,rated = True)
    modified_game_pd = scoreUserWeight(rated_game_pd)
    print("added username " + username)
    return modified_game_pd[['id', 'name', 'score']]

# %%
scoreUsernameRatings('TragicBandit')
# Out:
# added username TragicBandit
# Empty DataFrame
# Columns: [id, name, score]
# Index: []

# %%
scoreUsernameRatings('1000rpm')
# Out:
# added username 1000rpm
#          id                                      name  score
# 0       432                                  6 nimmt!    1.4
# 2    204516         878 Vikings: Invasions of England    1.4
# 3         5                                   Acquire    1.4
# 4     22545  Age of Empires III: The Age of Discovery    1.4
# 5     48726                           Alien Frontiers    1.4
# ..      ...                                       ...    ...
# 129  193105               Utopia Engine: Beast Hunter    1.4
# 130   15364                            Vegas Showdown    1.4
# 131   25821    The Werewolves of Miller&#039;s Hollow    1.4
# 132   33643                                Whoowasit?    1.4
# 133   27588                                Zooloretto    1.4
#
# [132 rows x 3 columns]

# %%
## create the game ranking matrix

game_recommendation_df = pd.DataFrame(columns = ['id', 'name', 'score'])


## get user id and associated board games
for index, value in username_df.items():        
    
    for i in range(3):
        try: 
            user_score_df = scoreUsernameRatings(value)
            break
        except:
            time.sleep(3)
            continue
            
    game_recommendation_df = pd.concat([game_recommendation_df, user_score_df], ignore_index = True)

print(game_recommendation_df)
# Out:
# added username 0lexandr
# added username 1000rpm
# added username 100pcBlade
# added username 144creations
# added username 14cross
# added username 16note
# added username 1amgreg77
# added username 1arska
# added username 1awesomeguy
# added username 1CHNUP
# added username 1point21gigawatts
# added username 1SkyCaptain
# added username 216stitches
# added username 234418803
# added username 2d20
# added username 2dTones
# added username 2goofy
# added username 2la_fr
# added username 2ndPlace
# added username 3davoli
# added username 3dragonfly
# added username 42n4
# added username 4th%20stringer
# added username 6element
# added username 6EQUJ5
# added username 700ravens
# added username 7guard
# added username 7Wonders500
# added username 80sGirl
# added username 8odoros
# added username A1790794268
# added username A1win
# added username A3RKev
# added username aaa37
# added username aadrian13
# added username aaj94
# added username aalotr13
# added username aardball
# added username Aardvark%20Sam
# added username aardwolf98
# added username aaronandre41
# added username AaronD
# added username AaronOziel
# added username Aarontu
# added username AayushM
# added username ab999
# added username abbottj83
# added username AbbundiMighe
# added username abkcppm
# added username abnormallyramsey
# added username Abom1nation
# added username 1%20Family%20Meeple
# added username 1905_CE3
# added username 19oldnewgamer53
# added username 1blindI
# added username 1e3er
# added username 1qwerty
# added username 20%20yards%20of%20linen
# added username 21n6y
# added username 22764636
# added username 2ndinBeautyContest
# added username 3ampsmith
# added username 3dicebombers
# added username 3urogamer
# added username 40crew
# added username 4Corners
# added username 4theta
# added username 8tlas
# added username A%20River%20Runs
# added username a37345735
# added username AAAlone
# added username aadorian
# added username Aahz339
# added username Abdul
# added username ABigOleBoat
# added username abssalom
# added username AbsZero
# added username aca83
# added username Acama
# added username ace1012003
# added username AceHenshin
# added username AcemanBR
# added username acharland
# added username Achire
# added username Acibara
# added username Acoidan85
# added username acooper1004
# added username acoustichero
# added username Acpudman
# added username Action%20Andy
# added username Actuarially
# added username adambadura
# added username AdamCatant
# added username adamhess89
# added username Adamkluke22
# added username adammale
# added username adamscott
# added username adamsd
# added username adamw
# added username Adanedhel
# added username 0%201%201%202%203%205%208
# added username 00daniel00
# added username 12thManStanding
# added username 1ndiana
# added username 1Wif
# added username 2gunmojo
# added username 414448
# added username 4wallz
# added username 56130316
# added username 65stangowner
# added username 75dragon
# added username 7thDRXN
# added username 8one6
# added username 9snick4
# added username aaarg_ink
# added username AADA7A
# added username aandrews
# added username AargleZymurgy
# added username aaronbush100
# added username aarondesk
# added username aasitus
# added username aautio
# added username AB%20Special
# added username Abasith50
# added username Abcdefgames
# added username Adams2108
# added username Axtium1
# added username Begger41
# added username birdsong703
# added username bngabletofly
# added username BoardGameReviewUK
# added username brazwhazz
# added username Bri8515
# added username Bridg_et1
# added username capitalgamer
# added username caradoc
# added username CarolineBlack
# added username Chuggas
# added username crunchbeast
# added username DarbyC
# added username Don%20Smith
# added username DrWildcat
# added username Ellyria
# added username Esebella
# added username ethomas25
# added username flash_baz
# added username furthing
# added username Gameschooling101
# added username GrimsEmbrace
# added username HeskoGames
# added username HitPointsGaming
# added username hugolin
# added username IndelibleKj
# added username IrekIsmaren
# added username IvanGrimm
# added username jakethedog000
# added username JugglinDan
# added username Justadol
# added username jwbellarby
# added username 11celle
# added username 13ewa12n
# added username 2Face
# added username 2kevin76
# added username 5398cane
# added username 5ummoning
# added username A%20Jaded%20Panda
# added username A15Smith
# added username aadrienns
# added username AaronCRdz
# added username aauten
# added username Abdurrahim%20Armagan
# added username abisashi
# added username ablebodiedman
# added username Abysmul
# added username aCardboardBox
# added username acatnamedjoe
# added username acekiller
# added username Achrilon
# added username AcHughes
# added username Adalbertus123
# added username adammurgs
# added username adamolanna
# added username adamredwoods
# added username AdamStarks
# added username adamtaylorhouston
# added username 3choplex
# added username 3kindsofsalt
# added username 42vines
# added username 48cg89tw
# added username 49xjohn
# added username 4ndrz
# added username 55Badger
# added username 5pencer
# added username 7he%20Architect
# added username 85bears
# added username 8thDay
# added username 95after5
# added username a2greg
# added username a4rino
# added username aalemos
# added username Aarong3eason
# added username AaronKI
# added username AaronPepo
# added username aaronseeber
# added username abc75162000
# added username aboveriver
# added username 28green
# added username 383cherokee
# added username 4ndrewcol3
# added username 4rch3r
# added username 88GJS88
# added username A5AX
# added username AandF
# added username aaron778
# added username AaronBE85
# added username aawhite1
# added username abalufaske
# added username abhijani97
# added username ablehat
# added username absalinas26
# added username absolutleo
# added username abweins
# added username AbyssinianSon
# added username AC0990
# added username ActivePuck
# added username ad116
# added username adamgospod
# added username adanryd
# added username ADarkKnightOfTheSoul
# added username adebahr84
# added username adelfaidah
# added username AdelinDumitru
# added username adomescik
# added username Adrian%20San
# added username aeaswen
# added username Aelcor
# added username aemorales2
# added username Aerdain
# added username AernoutMJC
# added username aeroguru1978
# added username AetherStrider
# added username afafard
# added username aFFekopp
# added username Afff3
# added username afjb
# added username agardner1993
# added username agentpatman
# added username -Morphling-
# added username 269Hawkmoon
# added username 35tango
# added username 360_Piranha
# added username 3EBC
# added username 3nails4holes
# added username 418Y
# added username 4x%20scalper
# added username 7Dahl7
# added username Aaje
# added username AaltimusPrime
# added username aaron182
# added username AARon78
# added username AaronDrakin
# added username AaronTargon
# added username abandofmilk
# added username abdula_
# added username abraham92
# added username AbramsTank00
# added username Abstract%20Paul
# added username abtrube
# added username Abyss_Raider
# added username acark
# added username accidentaldesign
# added username acookie
# added username AcroAndGames
# added username acrobat
# added username Adadu473
# added username Adam0n
# added username AdamCarr
# added username Adamh92
# added username adamisclassy
# added username adamphipps11
# added username adamscottstewart
# added username adamturner
# added username adamxt
# added username adam_0
# added username Adastra_KS
# added username Addiction2k
# added username adh105
# added username Adio75
# added username AdMan2015
# added username AdmiralBanana
#            id                                    name  score
# 0      230802                                    Azul    1.8
# 1      258036  Between Two Castles of Mad King Ludwig    1.8
# 2       34219                                 Biblios    1.8
# 3       28720                       Brass: Lancashire    1.8
# 4         822                             Carcassonne    1.8
# ...       ...                                     ...    ...
# 16738  283151                      Monikers: Classics    1.4
# 16739  167355                                 Nemesis    1.4
# 16740  244521               The Quacks of Quedlinburg    1.4
# 16741   92415                                   Skull    1.4
# 16742  123239                 Wits &amp; Wagers Party    1.4
#
# [16743 rows x 3 columns]

# %%
for index, value in full_collection_df['id'].items():
    if len(game_recommendation_df[game_recommendation_df['id'].isin([value])]) > 0:
        game_recommendation_df = game_recommendation_df.drop(game_recommendation_df[game_recommendation_df['id'] == value].index)

# %%
game_recommendation_df.set_index('id')
score_df = game_recommendation_df.groupby(['name']).sum()
score_df.sort_values(by = ['score'], ascending = False, inplace = True)


print(score_df.head(35))
# Out:
#                                      score
# name
# Terraforming Mars                    122.0
# Carcassonne                          116.6
# Azul                                 114.4
# 7 Wonders Duel                       110.2
# Codenames                             90.8
# Concordia                             89.4
# Puerto Rico                           87.6
# Race for the Galaxy                   86.6
# Agricola                              86.2
# The Quacks of Quedlinburg             86.0
# Patchwork                             85.4
# Jaipur                                81.0
# Love Letter                           78.4
# Lords of Waterdeep                    75.8
# King of Tokyo                         69.6
# Brass: Birmingham                     65.6
# Five Tribes                           64.2
# Cascadia                              63.6
# The Crew: The Quest for Planet Nine   61.6
# Everdell                              61.4
# Power Grid                            61.2
# Kingdomino                            61.0
# Ark Nova                              60.2
# Twilight Struggle                     59.0
# Small World                           57.8
# Lost Cities                           57.6
# Stone Age                             57.0
# Caverna: The Cave Farmers             56.8
# Dixit                                 56.6
# Spirit Island                         56.0
# Lost Ruins of Arnak                   52.6
# Ticket to Ride: Europe                52.6
# Great Western Trail                   52.6
# For Sale                              52.2
# Le Havre                              52.0
